# %% [markdown]
# # CLASS 03 ASSIGNMENT
# ### Name : Shreyit Sinha
# ### Roll no. : 027

# %% [markdown]
# ## Questions:

# %% [markdown]
# 1.	Find factorial of a number

# %%
import math
a=4
print(math.factorial(a))
# Out:
# 24

# %% [markdown]
# 2.	Generate random numbers

# %%
import random
print("Random no. 1: ",random.randint(1,100))
print("Random no. 2: ",random.randint(1,100))
print("Random no. 3: ",random.randint(1,100))
# Out:
# Random no. 1:  25
# Random no. 2:  62
# Random no. 3:  15

# %% [markdown]
# 3.	Find power of numbers

# %%
print("5^2=",math.pow(5,2))
print("5^3=",math.pow(5,3))
print("5^4=",math.pow(5,4))
# Out:
# 5^2= 25.0
# 5^3= 125.0
# 5^4= 625.0

# %% [markdown]
# 4.	 Calculate average of any 4 numbers

# %%
numbers = [10, 23, 32, 30, 44]
avg = sum(numbers) / len(numbers)
print(avg)
# Out:
# 27.8

# %% [markdown]
# 5.	 Find max of any 3 numbers

# %%
numbers = [10, 23, 32]
maxm = max(numbers)
print(maxm)
# Out:
# 32

# %% [markdown]
# 6.	 Sum of digits any 4 numbers

# %%
numbers = [10, 23, 32, 30, 44]
sumof_4 = sum(numbers)
print(sumof_4)
# Out:
# 139

# %% [markdown]
# 8.	Replace word

# %%
s = "I love F1"
print(s.replace("F1", "Nascar"))
# Out:
# I love Nascar

# %% [markdown]
# 9.	Split sentence

# %%
s = "I_love_F1"
print(s.split("_"))
# Out:
# ['I', 'love', 'F1']

# %% [markdown]
# 10.	Remove spaces

# %%
s = "I love F1"
print(s.replace(" ", ""))
# Out:
# IloveF1

# %% [markdown]
# 11.	Use Find function

# %%
print(s.find("F1")) # Gives index
# Out:
# 7

# %% [markdown]
# 12.	Capitalize text & lower text

# %%
print(s.upper())
print(s.lower())
# Out:
# I LOVE F1
# i love f1

# %% [markdown]
# 13.	Use strip function

# %%
s = "         I_love_F1"
print(s.strip())
# Out:
# I_love_F1
