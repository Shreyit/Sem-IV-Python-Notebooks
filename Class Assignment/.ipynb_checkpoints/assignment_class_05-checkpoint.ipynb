# %% [markdown]
# # Python Data Types - Theory Questions
# ## Numbers
# 1. What is int?
# 2. What is float?
# 3. What is complex?
# 4. Why use math module?
# 5. What is factorial?
# 6. What is randint?
# 7. Difference int and float?
# 8. Is number mutable or immutable?
#
# ## Strings
# 1. What is immutability?
# 2. What is slicing?
# 3. What is indexing?
# 4. Purpose of split?
# 5. Purpose of replace?
# 6. Why immutable?
# 7. Is string mutable or immutable?
# 8. What is default index position starts from?
#
# ## Lists
# 1. What is list?
# 2. append?
# 3. insert?
# 4. remove?
# 5. pop?
# 6. Is list mutable or immutable?
# 7. What is a nested list?
# 8.Why do we need list datatype?
#
# ## Dictionary
# 1. What is dictionary?
# 2. Do keys of dictionary need to be Unique? If yes why if no why?
# 3. get method?
# 4. update?
# 5. pop?
# 6. keys?
# 7. values?
# 8. Is dictionary mutable or immutable?
#
# ## Sets
# 1. What is set?
# 2. Why no duplicates?
# 3. Union?
# 4. Intersection?
# 5. Difference?
# 7. Use case?
# 8. Is set mutable or immutable?
#
# ## Tuples
# 1. What is tuple?
# 2. Why immutable?
# 3. What is Boolean?
# 4. What is immutable and mutable data types? Which data types are mutable & which are immutable?
